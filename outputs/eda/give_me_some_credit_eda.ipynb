# %% [markdown]
# # GiveMeSomeCredit — EDA
#
# Notebook này đọc dữ liệu và các bảng được tạo bởi `scripts/run_pipeline.py`. EDA chỉ dùng training split để tránh nhìn vào validation/test.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'eda':
    PROJECT_ROOT = PROJECT_ROOT.parents[1]
EDA_DIR = PROJECT_ROOT / 'outputs' / 'eda'
DATASET = PROJECT_ROOT / 'datasets' / 'processed' / 'cs-training-clean.csv'

# %% [markdown]
# ## Target distribution

# %%
pd.read_csv(EDA_DIR / 'target_distribution.csv')

# %% [markdown]
# ## Missing values

# %%
pd.read_csv(EDA_DIR / 'missing_summary.csv').head(10)

# %% [markdown]
# ## Anomalies và cách xử lý

# %%
pd.read_csv(EDA_DIR / 'anomaly_findings.csv')

# %% [markdown]
# ## Bad rate theo decile của 10 biến

# %%
deciles = pd.read_csv(EDA_DIR / 'bad_rate_by_decile.csv')
deciles.groupby('feature', sort=False).head(10)

# %% [markdown]
# ## Numeric summary

# %%
pd.read_csv(EDA_DIR / 'numeric_summary.csv')
